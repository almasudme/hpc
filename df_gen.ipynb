# %%
import pandas as pd
from glob import glob
import os
from tasks import parser
import librosa
import numpy as np
import time

# %%
train = pd.read_csv(os.path.join('train/train.csv'))
start= time.time()
for i in train.index:
    file_name = os.path.join("train","Train",str(train["ID"][i])+".wav")
    class_name = str(train["Class"][i])
    parser.apply_async([file_name,class_name,start])

# %% [markdown]
# # Wait untill all the csv files are created. Then execute the following cells.

# %%
csv_files = glob(os.path.join('csv_data','*.csv'))
print(csv_files)
# Out:
# ['csv_data\\0.csv', 'csv_data\\1.csv', 'csv_data\\2.csv', 'csv_data\\3.csv']

# %%
df_list = []
for file in csv_files:
    temp_df = pd.read_csv(file,index_col=None,header=None)
    df_list.append(temp_df)
df = pd.concat(df_list,axis = 0, ignore_index = True)

# %%
df
# Out:
#             0           1           2          3          4          5   \
# 0   -82.123589  139.505916  -42.430865  24.827861 -11.620764  23.497084
# 1  -110.229157   91.258987 -137.438967  57.104739 -42.575898  18.365831
# 2  -192.072282  132.090061  -98.849448   0.677415 -25.435389  -9.677655
# 3  -213.278788   89.323589  -55.256190  12.632100 -47.775379  14.702909
# 4   -55.400555   22.767319  -46.079867   8.980095 -29.806272  22.077936
# 5  -103.056817  164.846157  -15.676581  49.735848   9.312111  17.344044
# 6  -315.299200  184.212858   -6.580867  -0.341687 -10.026157  32.387084
# 7  -123.393651   15.181946  -50.093329   7.141872 -26.817033  -0.692504
# 8  -203.975530   83.958141  -66.730275  18.536461 -20.581497   1.906206
# 9  -199.528983  183.668969   -7.142848  10.107982 -11.258211  -0.348338
# 10  -15.744005  124.119960  -29.428881  39.447193 -23.501912  16.550815
# 11 -237.926479  135.902461   39.268440  21.240239   9.531328  13.885121
# ...
